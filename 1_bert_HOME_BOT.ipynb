# %% [raw]
# 2020-04-17 16:10:32
# 使用bert模型，训练HOME_BOT数据
#
# 需要checkpoint_path参数。
# 这个文件在bert下载的模型文件中，不存在。
#
# 先用plato的luwdig模型训练一遍

# %%
# !source env/bin/activate
# Out:
# /bin/sh: 1: source: not found

# %%
# !pip list
# Out:
# DEPRECATION: The default format will switch to columns in the future. You can use --format=(legacy|columns) (or define a format=(legacy|columns) in your pip.conf under the [list] section) to disable this warning.
# absl-py (0.9.0)
# Cython (0.29.16)
# h5py (2.10.0)
# joblib (0.14.1)
# ludwig (0.2.2.4)
# numpy (1.18.2)
# pandas (1.0.3)
# pip (9.0.1)
# pkg-resources (0.0.0)
# python-dateutil (2.8.1)
# pytz (2019.3)
# PyYAML (5.3.1)
# scikit-learn (0.22.2.post1)
# scipy (1.4.1)
# setuptools (39.0.1)
# six (1.14.0)
# tabulate (0.8.7)
# tqdm (4.45.0)

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/57/02/5432412c162989260fab61fa65e0a490c1872739eb91a659896e4d554b26/protobuf-3.11.3-cp36-cp36m-manylinux1_x86_64.whl
# ...

# %%
# !pip list
# Out:
# DEPRECATION: The default format will switch to columns in the future. You can use --format=(legacy|columns) (or define a format=(legacy|columns) in your pip.conf under the [list] section) to disable this warning.
# absl-py (0.9.0)
# astor (0.8.1)
# Cython (0.29.16)
# gast (0.3.3)
# google-pasta (0.2.0)
# grpcio (1.28.1)
# h5py (2.10.0)
# joblib (0.14.1)
# Keras-Applications (1.0.8)
# Keras-Preprocessing (1.1.0)
# ludwig (0.2.2.4)
# Markdown (3.2.1)
# numpy (1.18.2)
# pandas (1.0.3)
# pip (9.0.1)
# pkg-resources (0.0.0)
# protobuf (3.11.3)
# python-dateutil (2.8.1)
# pytz (2019.3)
# PyYAML (5.3.1)
# scikit-learn (0.22.2.post1)
# scipy (1.4.1)
# setuptools (46.1.3)
# six (1.14.0)
# tabulate (0.8.7)
# tensorboard (1.14.0)
# tensorflow (1.14.0)
# tensorflow-estimator (1.14.0)
# termcolor (1.1.0)
# tqdm (4.45.0)
# Werkzeug (1.0.1)
# wheel (0.34.2)
# wrapt (1.12.1)

# %%
# !pip install --upgrade pip
# Out:
# Cache entry deserialization failed, entry ignored
# ...
#   Using cached https://files.pythonhosted.org/packages/54/0c/d01aa759fdc501a58f431eb594a17495f15b88da142ce14b5845662c13f3/pip-20.0.2-py2.py3-none-any.whl
# ...
#   Found existing installation: pip 9.0.1
#     Uninstalling pip-9.0.1:
#       Successfully uninstalled pip-9.0.1
# ...

# %%
# !pip install tensorflow==1.15.2 -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      |████████████████████████████████| 110.5 MB 52 kB/s eta 0:00:012     |██████████████████████████▏     | 90.4 MB 82 kB/s eta 0:04:04     |████████████████████████████▎   | 97.8 MB 109 kB/s eta 0:01:56
# ...
#      |████████████████████████████████| 3.8 MB 59.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 503 kB 9.9 MB/s eta 0:00:01     |█████████████████████████▍      | 399 kB 9.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 353 kB/s eta 0:00:011
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7539 sha256=34b73c436edffaa56c470451d6d803ca99490c811afcfd3c9dde81be9a00a24b
#   Stored in directory: /home/xuehp/.cache/pip/wheels/7f/29/33/39057a768652bcbf21c1eab7e81a9ac598c433ae5c0e0f7deb
# Successfully built gast
# ...
#   Attempting uninstall: gast
#     Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# ...

# %%
# 训练checkpoint文件

# 1. 拷贝数据
#  scp /Users/huihui/data/metalwoz-v1/csv/HOME_BOT.csv xuehp@haomeiya002:~/git/ludwig/data/

# 2. 配置plato的yaml文件 
# yml/metalWOZ_seq2seq_ludwig.yaml

# 3. 训练模型

# !ludwig experiment  \
--model_definition_file yml/metalWOZ_seq2seq_ludwig.yaml \
--data_csv data/HOME_BOT.csv \
--output_directory models/HOME_BOT/
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.2.2.4 - Experiment
#
# Experiment name: experiment
# Model name: run
# Output path: models/HOME_BOT/experiment_run
#
#
# ludwig_version: '0.2.2.4'
# command: ('/home/xuehp/git/ludwig/env/bin/ludwig experiment --model_definition_file '
#  'yml/metalWOZ_seq2seq_ludwig.yaml --data_csv data/HOME_BOT.csv '
#  '--output_directory models/HOME_BOT/')
# commit_hash: '3cb226cff578'
# random_seed: 42
# ...

# %% [raw]
# 2020-04-17 16:39:10 训练完成
#
# perplexity: 2.8910489792519427
# token_accuracy: 0.2387041160836147
#
# Finished: experiment_run
# Saved to: models/HOME_BOT/experiment_run

# %% [raw]
# 准备bert的预训练模型文件
#
#  cd bert_models/
#  wget https://storage.googleapis.com/bert_models/2020_02_20/uncased_L-2_H-128_A-2.zip
#  直接从sougou mrc 目录拷贝了一份

# %% [raw]
# 以上，用plato的luwdig模型训练HOME_BOT数据，完成。
#
# 下一步，使用bert在现有基础之上，再次训练
